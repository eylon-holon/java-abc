# %%
from eylon.core import *
grade = int(input("Please enter your grade: "))
print(post_my_grade("self-grade", grade))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 from eylon.core import *
#       2 grade = int(input("Please enter your grade: "))
# ----> 3 print(post_my_grade("self-grade", grade))
#
# File /workspaces/java-abc/eylon/core.py:94, in post_my_grade(name, grade)
#      83 student = get_current_branch()
#      84 request = {
#      85     'now': datetime.datetime.now().isoformat(),
#      86     'docId': cfg.docId,
#    (...)
#      92     'tags': ""
#      93 }
# ---> 94 response = post(api, request)
#      95 return response["msg"]
#
# File /workspaces/java-abc/eylon/post.py:7, in post(url, data)
#       5 payload = json.dumps(data)
#       6 request = Request(url, payload.encode())
# ----> 7 with urlopen(request) as response:
#       8     data = response.read().decode()
#       9     return json.loads(data)
#
# ...
