# %% [markdown]
# ## [🎦](https://youtu.be/nD_IpImbgWU)

# %% [markdown]
# | סיבוכיות זמן ריצה  | הסבר      |
# |---                    |---    |
# | $O(1)$     |  כמות הפעולות לא תלויה בגודל הקלט     |
# | $O(n)$     |  עבור כל איבר בקלט יש כמות קבועה וידועה מראש של פעולות <br> _הכי נפוץ במבחנים_  |
# | $O(n^2)$     | עבור כל איבר בקלט כמות הפעולות תלויה בגודל הקלט     |

# %% [markdown]
# <table>
#   <tr>
#     <th>דוגמה של קוד</th>
#     <th>סיבוכיות</th>
#     <th>נימוק</th>
#   </tr>
#   <tr>
#     <td><pre style="font-size:24px">
# Queue< Integer> que = ...;
# int x = que.head()
#     </td>
#     <td><pre>
# O(1)
#     </td>
#     <td><pre style="font-size:32px;text-align:right;">
# לוקחים איבר ראשון של התור
# כמות הפעולות קבועה וידועה מראש
#     </td>
#   </tr>
#   <tr>
#     <td><pre style="font-size:24px">
# int max = a[0];
# for (int i = 0; i < 3; i++) {
#     if (a[i] > max) {
#         max = a[i];
#     }
# }
#     </td>
#     <td><pre>
# O(1)
#     </td>
#     <td><pre style="font-size:32px;text-align:right;">
# מוצאים ערך מקסימום בין <b>שלושה</b> איברים של מערך
# כמות פעולות קבועה וידועה מראש
#     </td>
#   </tr>
#   <tr>
#     <td><pre style="font-size:24px">
# Node< Student> list = ...;
# countNodes(list);
#     </td>
#     <td><pre>
# O(n)
#     </td>
#     <td><pre style="font-size:32px;text-align:right;">
# עוברים פעם אחת על כל איבר של הקלט
#     </td>
#   </tr>
#   <tr>
#     <td><pre style="font-size:24px">
# for (int i = 0; i < a.length; i++) {
#     int sum = 0;
#     for (int j = 0; j < 10; j++) {
#         sum += a[i];
#         ...
#     }
# }
#     </td>
#     <td><pre>
# O(n)
#     </td>
#     <td><pre style="font-size:32px;text-align:right;">
# עוברים על כל איבר של הקלט 10 פעמים
# כמות קבועה וידועה מראש של פעולות עבור כל איבר
#     </td>
#   </tr>
#   <tr>
#     <td><pre style="font-size:24px">
# for (int j = 0; j < 10; j++) {
#     int min = a[0];
#     for (int i = 0; i < a.length; i++) {
#         ...
#     }
# }
#     </td>
#     <td><pre>
# O(n)
#     </td>
#     <td><pre style="font-size:32px;text-align:right;">
# עוברים 10 פעמים על מערך נתון
# כמות קבועה וידועה מראש של פעולות עבור כל איבר
#     </td>
#   </tr>
#   <tr>
#     <td><pre style="font-size:24px">
# for (int i = 0; i < a.length; i++) {
#     for (int j = 0; j < i; j++) {
#         ...
#     }
# }
#     </td>
#     <td><pre>
# O(n^2)
#     </td>
#     <td><pre style="font-size:32px;text-align:right;">
# כמות הפעולות עבור כל איבר במערך
# תלויה בגודל של מערך עצמו
#     </td>
#   </tr>
#   </tr>
#   <tr>
#     <td><pre style="font-size:24px">
# Node< Integer> list = ...;
# Node< Integer> node = list;
# while (node != null) {
#     search(list, node.getValue());
#     ...
# }
#     </td>
#     <td><pre>
# O(n^2)
#     </td>
#     <td><pre style="font-size:32px;text-align:right;">
# בשביל למצוא משהוא ברשימה חייבים לעבור על כל איבריה
# מחפשים עבור כל איבר של רשימה
# כמות פעולות עבור כל איבר של הקלט תלויה בגודל הקלט
#     </td>
#   </tr>
# </table>
